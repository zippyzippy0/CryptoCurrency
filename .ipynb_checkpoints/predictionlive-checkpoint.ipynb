# %%
import yfinance as yf
import os
import pandas as pd

# %%
btc_ticker = yf.Ticker("BTC-USD")

# %%
btc =  btc_ticker.history(period ="max")

btc.index = btc.index.tz_localize(None)

# %%
btc
# Out:
#                     Open          High           Low         Close  \
# Date
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2024-09-14  60569.117188  60656.722656  59517.882812  60005.121094
# 2024-09-15  60000.726562  60381.917969  58696.308594  59182.835938
# 2024-09-16  59185.226562  59205.511719  57501.339844  58192.507812
# 2024-09-17  58192.507812  61316.089844  57628.070312  60308.539062
# 2024-09-19  61760.109375  62501.035156  61609.867188  61955.156250
#
#                  Volume  Dividends  Stock Splits
# Date
# 2014-09-17     21056800        0.0           0.0
# 2014-09-18     34483200        0.0           0.0
# 2014-09-19     37919700        0.0           0.0
# 2014-09-20     36863600        0.0           0.0
# 2014-09-21     26580100        0.0           0.0
# ...                 ...        ...           ...
# 2024-09-14  16428405496        0.0           0.0
# 2024-09-15  18120960867        0.0           0.0
# 2024-09-16  32032822113        0.0           0.0
# 2024-09-17  38075570118        0.0           0.0
# 2024-09-19  45829410816        0.0           0.0
#
# [3655 rows x 7 columns]

# %%
btc.index = pd.to_datetime(btc.index)

# %%
del btc["Dividends"]
del btc["Stock Splits"]

# %%
btc.columns = [c.lower() for c in btc.columns]

# %%
btc.plot.line(y="close", use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %%
wiki = pd.read_csv("wikipedia_edits.csv", index_col=0, parse_dates = True)

# %%
wiki
# Out:
#             edit_count  sentiment  neg_sentiment
# 2009-04-07    0.000000   0.000000       0.000000
# 2009-04-08    0.000000   0.000000       0.000000
# 2009-04-09    0.000000   0.000000       0.000000
# 2009-04-10    0.000000   0.000000       0.000000
# 2009-04-11    0.000000   0.000000       0.000000
# ...                ...        ...            ...
# 2024-09-05    0.166667  -0.000646       0.066667
# 2024-09-06    0.133333  -0.033901       0.066667
# 2024-09-07    0.133333  -0.033901       0.066667
# 2024-09-08    0.133333  -0.033901       0.066667
# 2024-09-09    0.133333  -0.033901       0.066667
#
# [5635 rows x 3 columns]

# %%
btc = btc.merge(wiki, left_index = True, right_index=True)

# %%
btc
# Out:
#                     open          high           low         close  \
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2024-09-05  57971.703125  58300.582031  55712.453125  56160.488281
# 2024-09-06  56160.191406  56976.109375  52598.699219  53948.753906
# 2024-09-07  53949.085938  54838.144531  53740.070312  54139.687500
# 2024-09-08  54147.933594  55300.859375  53653.757812  54841.566406
# 2024-09-09  54851.886719  58041.125000  54598.433594  57019.535156
#
#                  volume  edit_count  sentiment  neg_sentiment
# 2014-09-17     21056800    5.033333  -0.292484       0.568057
# 2014-09-18     34483200    5.066667  -0.293053       0.568057
# 2014-09-19     37919700    5.200000  -0.323301       0.601390
# 2014-09-20     36863600    5.200000  -0.292914       0.584723
# 2014-09-21     26580100    5.233333  -0.292837       0.584723
# ...                 ...         ...        ...            ...
# 2024-09-05  31030280656    0.166667  -0.000646       0.066667
# 2024-09-06  49361693566    0.133333  -0.033901       0.066667
# 2024-09-07  19061486526    0.133333  -0.033901       0.066667
# 2024-09-08  18268287531    0.133333  -0.033901       0.066667
# 2024-09-09  34618096173    0.133333  -0.033901       0.066667
#
# [3646 rows x 8 columns]

# %%
btc["tomorrow"] = btc["close"].shift(-1)

# %%
btc
# Out:
#                     open          high           low         close  \
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2024-09-05  57971.703125  58300.582031  55712.453125  56160.488281
# 2024-09-06  56160.191406  56976.109375  52598.699219  53948.753906
# 2024-09-07  53949.085938  54838.144531  53740.070312  54139.687500
# 2024-09-08  54147.933594  55300.859375  53653.757812  54841.566406
# 2024-09-09  54851.886719  58041.125000  54598.433594  57019.535156
#
#                  volume  edit_count  sentiment  neg_sentiment      tomorrow
# 2014-09-17     21056800    5.033333  -0.292484       0.568057    424.440002
# 2014-09-18     34483200    5.066667  -0.293053       0.568057    394.795990
# 2014-09-19     37919700    5.200000  -0.323301       0.601390    408.903992
# 2014-09-20     36863600    5.200000  -0.292914       0.584723    398.821014
# 2014-09-21     26580100    5.233333  -0.292837       0.584723    402.152008
# ...                 ...         ...        ...            ...           ...
# 2024-09-05  31030280656    0.166667  -0.000646       0.066667  53948.753906
# 2024-09-06  49361693566    0.133333  -0.033901       0.066667  54139.687500
# 2024-09-07  19061486526    0.133333  -0.033901       0.066667  54841.566406
# 2024-09-08  18268287531    0.133333  -0.033901       0.066667  57019.535156
# 2024-09-09  34618096173    0.133333  -0.033901       0.066667           NaN
#
# [3646 rows x 9 columns]

# %%
btc["target"] = (btc["tomorrow"] > btc["close"]).astype(int)

# %%
btc["target"].value_counts()
# Out:
# target
# 1    1925
# 0    1721
# Name: count, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, min_samples_split=50,random_state=1)

train= btc.iloc[:-200]
test = btc[-200:]

predictors = ["close", "volume", "high", "low", "edit_count", "sentiment", "neg_sentiment"]
model.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=50, random_state=1)

# %%
from sklearn.metrics import precision_score

preds = model.predict(test[predictors])
preds = pd.Series(preds, index=test.index)
precision_score(test["target"], preds)
# Out:
# 0.5652173913043478

# %%
def predict(train, test, model, predictors):
    model.fit(train[predictors], train["target"])
    preds = model.predict(test[predictors])
    return pd.Series(preds, index=test.index, name="predictions")

# %%
def backtest(data, model, predictors, start=0, step=1):
    all_predictions = []
    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test, model, predictors)
        # Include the actual target values in the predictions DataFrame
        predictions = pd.concat([test["target"], predictions], axis=1)
        all_predictions.append(predictions)
    return pd.concat(all_predictions)

# %%
from xgboost import XGBClassifier

# Create the XGBoost model
model = XGBClassifier(random_state=1, learning_rate=.1, n_estimators=200)

# Run the backtest
predictions = backtest(btc, model, predictors)

# %%
# Calculate precision score
precision_score(predictions["target"], predictions["predictions"])

# %%
def compute_rolling(btc):
    horizons = [2,7,60,365]
    new_predictors = ["close", "sentiment", "neg_sentiment"]

    for horizon in horizons:
        rolling_averages = btc.rolling(horizon,min_peripds=1).mean()
        
        ratio_column = f"close_ratio_{horizon}"
        btc[ratio_column] = btc["close"]/rolling_averages["close"]

        edit_column = f"edit_{horizon}"
        btc[edit_column] = rolling_averages["edit_count"]

        rolling = btc.rolling(horizon,closed="left", min_periods=1).mean()
        trend_column = f"trend_{horizons}"
        btc[trend_column] = rolling["target"]
        
        new_predictors += [ratio_column, trend_column, edit_column]
    return btc, new_predictors

# %%
btc, new_predictors = compute_rolling(btc.copy())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 btc, new_predictors = compute_rolling(btc.copy())
#
# NameError: name 'btc' is not defined

# %%
btc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 btc
#
# NameError: name 'btc' is not defined

# %%
predictions = backtest(btc, model, new_predictors)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 predictions = backtest(btc, model, new_predictors)
#
# NameError: name 'backtest' is not defined

# %%
precision_score(predictions["target"], predictions["predictions"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 precision_score(predictions["target"], predictions["predictions"])
#
# NameError: name 'precision_score' is not defined

# %%
predictions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 predictions
#
# NameError: name 'predictions' is not defined
